# %% [markdown]
# # Azure OpenAI Pricing Tool
#
# Fetch Azure OpenAI pricing data using the Azure Retail Prices API.
#
# ## Features
# - 🔍 Search for specific models (e.g., GPT-4o, GPT-4 Turbo)
# - 🌍 Filter by Azure regions
# - 💱 Support for multiple currencies
# - 📊 Clean, formatted output
# - 🔄 Automatic pagination handling
#
# ### Parameters for `get_aoai_prices()`:
# - `region` - Azure region (e.g., "swedencentral", "westeurope")
# - `model_substr` - Model name substring (e.g., "gpt-4o", "GPT-4 Turbo")
# - `currency` - Currency code (e.g., "USD", "EUR", "SEK")
# - `product_name` - Service name (default: "Azure OpenAI")

# %%
from datetime import datetime
from typing import Dict, List

import requests
import pandas as pd

_API_ROOT = "https://prices.azure.com/api/retail/prices"
_API_VERSION = "2023-01-01-preview"
_HEADERS = {"User-Agent": "aoai-pricing-jupyter/1.0"}


def _get_all_items(params: Dict) -> List[Dict]:
    """Get all price rows, handling pagination automatically."""
    all_items = []
    url = _API_ROOT  # Initialize the URL!

    while url:
        response = requests.get(
            url,  # Use the current URL (first time: _API_ROOT, later: NextPageLink)
            params=params if url == _API_ROOT else None,  # Only send params on first request
            headers=_HEADERS,
            timeout=30,
        )
        response.raise_for_status()
        data = response.json()

        all_items.extend(data["Items"])
        url = data.get("NextPageLink")  # None when no more pages, required if result set>1000 items

    return all_items


def get_aoai_prices(
    region: str = "swedencentral",
    model_substr: str = "gpt-4o",
    currency: str = "USD",
    product_name: str = "Azure OpenAI",
) -> pd.DataFrame:
    """
    Return a DataFrame of Azure OpenAI retail prices.

    Parameters
    ----------
    region : str
        Azure ARM region code (e.g. 'westeurope', 'swedencentral').
    model_substr : str
        Substring matched against `meterName`. Case-sensitive!!!!
    currency : str
        ISO currency code ('USD', 'EUR', 'SEK', …).
    product_name : Azure OpenAI
        The product name to filter by, e.g. 'Azure OpenAI'.
    """
    filters = [
        f"armRegionName eq '{region}'",
        f"productName eq '{product_name}'",
        f"contains(meterName,'{model_substr}')",
        "priceType eq 'Consumption'",
    ]
    params: Dict[str, str] = {
        "api-version": _API_VERSION,
        "$filter": " and ".join(filters),
        "currencyCode": currency,
    }

    rows = _get_all_items(params)
    if not rows:
        raise ValueError(
            "No meters matched your filters. "
            "Double-check the region spelling and be sure the model substring's case matches "
            "exactly what the portal shows (e.g. 'GPT-4o', not 'gpt-4o')."
        )

    df = pd.DataFrame(rows)
    df["price_per_million"] = df["unitPrice"] * 1_000
    return df[
        [
            "meterName",
            "armRegionName",
            "currencyCode",
            "unitOfMeasure",
            "unitPrice",
            "price_per_million",
        ]
    ].sort_values("meterName")


print("Helper loaded:", datetime.utcnow().strftime("%Y-%m-%d %H:%M UTC"))
# Out:
# Helper loaded: 2025-07-28 08:29 UTC

# %%
regions = ["swedencentral", "westeurope"]
dfs = []

for region in regions:
    df = get_aoai_prices(region=region, model_substr="gpt-4o", currency="USD")
    dfs.append(df)

# %% [markdown]
# ## Display Results

# %%
for i, region in enumerate(regions):
    print(f"{'==='*15} {region.upper()} {'==='*15}")
    print(f"{'Model':<52} {'Unit':<12} {'$/1K tokens':<12} {'$/1M tokens':<12} {'Region':<15}")
    print("-" * 105)

    for _, row in dfs[i].iterrows():
        model_name = row['meterName'][:50] + "..." if len(row['meterName']) > 33 else row['meterName']
        print(
            f"{model_name:<52} "
            f"{row['unitOfMeasure']:<12} "
            f"${row['unitPrice']:<11.6f} "
            f"${row['price_per_million']:<11.2f} "
            f"{row['armRegionName']:<15}"
        )
    print("\n")
# Out:
# ============================================= SWEDENCENTRAL =============================================
# Model                                                Unit         $/1K tokens  $/1M tokens  Region
# ---------------------------------------------------------------------------------------------------------
# gpt-4o-0806-Batch-Inp-glbl Tokens                    1K           $0.001250    $1.25        swedencentral
# gpt-4o-0806-Batch-Outp-glbl Tokens...                1K           $0.005000    $5.00        swedencentral
# gpt-4o-0806-FT-Hstng-glbl Unit                       1 Hour       $1.700000    $1700.00     swedencentral
# gpt-4o-0806-FT-Hstng-regnl Unit                      1 Hour       $1.700000    $1700.00     swedencentral
# gpt-4o-0806-FT-Trng-glbl tkn Tokens...               1K           $0.025000    $25.00       swedencentral
# gpt-4o-0806-FT-Trng-regnl tkn Tokens...              1K           $0.027500    $27.50       swedencentral
# gpt-4o-0806-FT-inp-glbl Tokens                       1K           $0.002500    $2.50        swedencentral
# gpt-4o-0806-FT-inp-regnl Tokens                      1K           $0.002750    $2.75        swedencentral
# gpt-4o-0806-FT-outp-glbl Tokens                      1K           $0.010000    $10.00       swedencentral
# gpt-4o-0806-FT-outp-regnl Tokens                     1K           $0.011000    $11.00       swedencentral
# gpt-4o-0806-Inp-glbl Tokens                          1K           $0.002500    $2.50        swedencentral
# gpt-4o-0806-Inp-regnl Tokens                         1K           $0.002750    $2.75        swedencentral
# gpt-4o-0806-Outp-glbl Tokens                         1K           $0.010000    $10.00       swedencentral
# gpt-4o-0806-Outp-regnl Tokens                        1K           $0.011000    $11.00       swedencentral
# gpt-4o-0806-cached-FT-inp-glbl Tokens...             1K           $0.001250    $1.25        swedencentral
# gpt-4o-0806-cached-FT-inp-regnl Tokens...            1K           $0.001513    $1.51        swedencentral
# gpt-4o-64k-outp-alpha-0730-Inp-glbl Tokens...        1K           $0.006000    $6.00        swedencentral
# gpt-4o-64k-outp-alpha-0730-Outp-glbl Tokens...       1K           $0.018000    $18.00       swedencentral
# gpt-4o-64k-outp-alpha-Inp-regnl Tokens...            1K           $0.006600    $6.60        swedencentral
# gpt-4o-64k-outp-alpha-Outp-regnl Tokens...           1K           $0.019800    $19.80       swedencentral
# gpt-4o-aud-0603 Inp DZone Tokens                     1K           $0.044000    $44.00       swedencentral
# gpt-4o-aud-0603 Inp glbl Tokens                      1K           $0.040000    $40.00       swedencentral
# gpt-4o-aud-0603 Inp regnl Tokens                     1K           $0.048400    $48.40       swedencentral
# gpt-4o-aud-0603 Outp DZone Tokens                    1K           $0.088000    $88.00       swedencentral
# gpt-4o-aud-0603 Outp glbl Tokens                     1K           $0.080000    $80.00       swedencentral
# gpt-4o-aud-0603 Outp regnl Tokens                    1K           $0.096800    $96.80       swedencentral
# gpt-4o-aud-0603-txt Inp DZone Tokens...              1K           $0.002750    $2.75        swedencentral
# gpt-4o-aud-0603-txt Inp glbl Tokens...               1K           $0.002500    $2.50        swedencentral
# gpt-4o-aud-0603-txt Inp regnl Tokens...              1K           $0.003025    $3.02        swedencentral
# gpt-4o-aud-0603-txt Outp DZone Tokens...             1K           $0.011000    $11.00       swedencentral
# gpt-4o-aud-0603-txt Outp glbl Tokens...              1K           $0.010000    $10.00       swedencentral
# gpt-4o-aud-0603-txt Outp regnl Tokens...             1K           $0.012100    $12.10       swedencentral
# gpt-4o-aud-1217 Inp DZone Tokens                     1K           $0.044000    $44.00       swedencentral
# gpt-4o-aud-1217 Inp glbl Tokens                      1K           $0.040000    $40.00       swedencentral
# gpt-4o-aud-1217 Inp regnl Tokens                     1K           $0.048400    $48.40       swedencentral
# gpt-4o-aud-1217 Outp DZone Tokens                    1K           $0.088000    $88.00       swedencentral
# gpt-4o-aud-1217 Outp glbl Tokens                     1K           $0.080000    $80.00       swedencentral
# gpt-4o-aud-1217 Outp regnl Tokens                    1K           $0.096800    $96.80       swedencentral
# gpt-4o-aud-1217-txt Inp DZone Tokens...              1K           $0.002750    $2.75        swedencentral
# gpt-4o-aud-1217-txt Inp glbl Tokens...               1K           $0.002500    $2.50        swedencentral
# gpt-4o-aud-1217-txt Inp regnl Tokens...              1K           $0.003025    $3.02        swedencentral
# gpt-4o-aud-1217-txt Outp DZone Tokens...             1K           $0.011000    $11.00       swedencentral
# gpt-4o-aud-1217-txt Outp glbl Tokens...              1K           $0.010000    $10.00       swedencentral
# gpt-4o-aud-1217-txt Outp regnl Tokens...             1K           $0.012100    $12.10       swedencentral
# gpt-4o-ft model grader cched inpt Tokens...          1K           $0.001375    $1.38        swedencentral
# gpt-4o-ft model grader input Tokens...               1K           $0.002750    $2.75        swedencentral
# gpt-4o-ft model grader output Tokens...              1K           $0.011000    $11.00       swedencentral
# gpt-4o-mini-0718-Batch-Inp-glbl Tokens...            1K           $0.000075    $0.07        swedencentral
# gpt-4o-mini-0718-Batch-Outp-glbl Tokens...           1K           $0.000300    $0.30        swedencentral
# gpt-4o-mini-0718-FT-Hstng-glbl Unit...               1 Hour       $1.700000    $1700.00     swedencentral
# gpt-4o-mini-0718-FT-Hstng-regnl Unit...              1 Hour       $1.700000    $1700.00     swedencentral
# gpt-4o-mini-0718-FT-Outp-glbl Tokens...              1K           $0.000600    $0.60        swedencentral
# gpt-4o-mini-0718-FT-Trng-glbl Tokens...              1K           $0.003000    $3.00        swedencentral
# gpt-4o-mini-0718-FT-Trng-regnl Tokens...             1K           $0.003300    $3.30        swedencentral
# gpt-4o-mini-0718-FT-inp-glbl Tokens...               1K           $0.000150    $0.15        swedencentral
# gpt-4o-mini-0718-FT-inp-regnl Tokens...              1K           $0.000165    $0.17        swedencentral
# gpt-4o-mini-0718-FT-outp-regnl Tokens...             1K           $0.000660    $0.66        swedencentral
# gpt-4o-mini-0718-Inp-glbl Tokens                     1K           $0.000150    $0.15        swedencentral
# gpt-4o-mini-0718-Inp-regnl Tokens                    1K           $0.000165    $0.17        swedencentral
# gpt-4o-mini-0718-Outp-glbl Tokens                    1K           $0.000600    $0.60        swedencentral
# gpt-4o-mini-0718-Outp-regnl Tokens...                1K           $0.000660    $0.66        swedencentral
# gpt-4o-mini-0718-cached-FT-inp-glbl Tokens...        1K           $0.000075    $0.07        swedencentral
# gpt-4o-mini-0718-cached-FT-inp-regnl Tokens...       1K           $0.000091    $0.09        swedencentral
# gpt-4o-mini-ft mdel grdr cched inpt Tokens...        1K           $0.000083    $0.08        swedencentral
# gpt-4o-mini-ft model grader input Tokens...          1K           $0.000165    $0.17        swedencentral
# gpt-4o-mini-ft model grader output Tokens...         1K           $0.000660    $0.66        swedencentral
# gpt-4o-mini-transcribe-aud-inp-dz Tokens...          1K           $0.003300    $3.30        swedencentral
# gpt-4o-mini-transcribe-aud-inp-glbl Tokens...        1K           $0.003000    $3.00        swedencentral
# gpt-4o-mini-transcribe-aud-inp-rgnl Tokens...        1K           $0.003630    $3.63        swedencentral
# gpt-4o-mini-transcribe-txt-inp-dz Tokens...          1K           $0.001375    $1.38        swedencentral
# gpt-4o-mini-transcribe-txt-inp-glbl Tokens...        1K           $0.001250    $1.25        swedencentral
# gpt-4o-mini-transcribe-txt-inp-rgnl Tokens...        1K           $0.001513    $1.51        swedencentral
# gpt-4o-mini-transcribe-txt-out-dz Tokens...          1K           $0.005500    $5.50        swedencentral
# gpt-4o-mini-transcribe-txt-out-glbl Tokens...        1K           $0.005000    $5.00        swedencentral
# gpt-4o-mini-transcribe-txt-out-rgnl Tokens...        1K           $0.006050    $6.05        swedencentral
# gpt-4o-mini-tts-aud-out-dz Tokens                    1K           $0.013200    $13.20       swedencentral
# gpt-4o-mini-tts-aud-out-glbl Tokens...               1K           $0.012000    $12.00       swedencentral
# gpt-4o-mini-tts-aud-out-rgnl Tokens...               1K           $0.014520    $14.52       swedencentral
# gpt-4o-mini-tts-txt-inp-dz Tokens                    1K           $0.000660    $0.66        swedencentral
# gpt-4o-mini-tts-txt-inp-glbl Tokens...               1K           $0.000600    $0.60        swedencentral
# gpt-4o-mini-tts-txt-inp-rgnl Tokens...               1K           $0.000726    $0.73        swedencentral
# gpt-4o-rt-aud-0603 Inp DZone Tokens...               1K           $0.044000    $44.00       swedencentral
# gpt-4o-rt-aud-0603 Inp glbl Tokens...                1K           $0.040000    $40.00       swedencentral
# gpt-4o-rt-aud-0603 Inp regnl Tokens...               1K           $0.048400    $48.40       swedencentral
# gpt-4o-rt-aud-0603 Outp DZone Tokens...              1K           $0.088000    $88.00       swedencentral
# gpt-4o-rt-aud-0603 Outp glbl Tokens...               1K           $0.080000    $80.00       swedencentral
# gpt-4o-rt-aud-0603 Outp regnl Tokens...              1K           $0.096800    $96.80       swedencentral
# gpt-4o-rt-aud-0603 cchd Inp DZn Tokens...            1K           $0.002750    $2.75        swedencentral
# gpt-4o-rt-aud-0603 cchd Inp glbl Tokens...           1K           $0.002500    $2.50        swedencentral
# gpt-4o-rt-aud-0603 cchd Inp rgnl Tokens...           1K           $0.003025    $3.02        swedencentral
# gpt-4o-rt-aud-1217 Inp DZone Tokens...               1K           $0.044000    $44.00       swedencentral
# gpt-4o-rt-aud-1217 Inp glbl Tokens...                1K           $0.040000    $40.00       swedencentral
# gpt-4o-rt-aud-1217 Inp regnl Tokens...               1K           $0.048400    $48.40       swedencentral
# gpt-4o-rt-aud-1217 Outp DZone Tokens...              1K           $0.088000    $88.00       swedencentral
# gpt-4o-rt-aud-1217 Outp glbl Tokens...               1K           $0.080000    $80.00       swedencentral
# gpt-4o-rt-aud-1217 Outp regnl Tokens...              1K           $0.096800    $96.80       swedencentral
# gpt-4o-rt-aud-1217 cchd Inp DZn Tokens...            1K           $0.002750    $2.75        swedencentral
# gpt-4o-rt-aud-1217 cchd Inp glbl Tokens...           1K           $0.002500    $2.50        swedencentral
# gpt-4o-rt-aud-1217 cchd Inp rgnl Tokens...           1K           $0.003025    $3.02        swedencentral
# gpt-4o-rt-txt-0603 Inp DZone Tokens...               1K           $0.005500    $5.50        swedencentral
# gpt-4o-rt-txt-0603 Inp glbl Tokens...                1K           $0.005000    $5.00        swedencentral
# gpt-4o-rt-txt-0603 Inp regnl Tokens...               1K           $0.006050    $6.05        swedencentral
# gpt-4o-rt-txt-0603 Outp DZone Tokens...              1K           $0.022000    $22.00       swedencentral
# gpt-4o-rt-txt-0603 Outp glbl Tokens...               1K           $0.020000    $20.00       swedencentral
# gpt-4o-rt-txt-0603 Outp regnl Tokens...              1K           $0.024200    $24.20       swedencentral
# gpt-4o-rt-txt-0603 cchd Inp DZn Tokens...            1K           $0.002750    $2.75        swedencentral
# gpt-4o-rt-txt-0603 cchd Inp glbl Tokens...           1K           $0.002500    $2.50        swedencentral
# gpt-4o-rt-txt-0603 cchd Inp rgnl Tokens...           1K           $0.003025    $3.02        swedencentral
# gpt-4o-rt-txt-1217 Inp DZone Tokens...               1K           $0.005500    $5.50        swedencentral
# gpt-4o-rt-txt-1217 Inp glbl Tokens...                1K           $0.005000    $5.00        swedencentral
# gpt-4o-rt-txt-1217 Inp regnl Tokens...               1K           $0.006050    $6.05        swedencentral
# gpt-4o-rt-txt-1217 Outp DZone Tokens...              1K           $0.022000    $22.00       swedencentral
# gpt-4o-rt-txt-1217 Outp glbl Tokens...               1K           $0.020000    $20.00       swedencentral
# gpt-4o-rt-txt-1217 Outp regnl Tokens...              1K           $0.024200    $24.20       swedencentral
# gpt-4o-rt-txt-1217 cchd Inp DZn Tokens...            1K           $0.002750    $2.75        swedencentral
# gpt-4o-rt-txt-1217 cchd Inp glbl Tokens...           1K           $0.002500    $2.50        swedencentral
# gpt-4o-rt-txt-1217 cchd Inp rgnl Tokens...           1K           $0.003025    $3.02        swedencentral
# gpt-4o-transcribe-aud-inp-dz Tokens...               1K           $0.006600    $6.60        swedencentral
# gpt-4o-transcribe-aud-inp-glbl Tokens...             1K           $0.006000    $6.00        swedencentral
# gpt-4o-transcribe-aud-inp-rgnl Tokens...             1K           $0.007260    $7.26        swedencentral
# gpt-4o-transcribe-txt-inp-dz Tokens...               1K           $0.002750    $2.75        swedencentral
# gpt-4o-transcribe-txt-inp-glbl Tokens...             1K           $0.002500    $2.50        swedencentral
# gpt-4o-transcribe-txt-inp-rgnl Tokens...             1K           $0.003025    $3.02        swedencentral
# gpt-4o-transcribe-txt-out-dz Tokens...               1K           $0.011000    $11.00       swedencentral
# gpt-4o-transcribe-txt-out-glbl Tokens...             1K           $0.010000    $10.00       swedencentral
# gpt-4o-transcribe-txt-out-rgnl Tokens...             1K           $0.012100    $12.10       swedencentral
